# %%
import pandas as pd 
import matplotlib.pyplot as plt
dataS = pd.read_csv('udemy.csv')
# ** clean dataS In the section name 'course level' **
dataS = dataS[dataS['course level'] != 'Current price: $16.99']
dataS = dataS[dataS['course level'] != 'Current price: $19.99']
dataS = dataS[dataS['reviews'] != '0 reviews']

# %%
dataS['instructors'].value_counts().head(20)
# Out:
# instructors
# Packt Publishing                              134
# Mammoth Interactive, John Bura                 27
# Jones Granatyr, IA Expert Academy              26
# Exam Turf                                      25
# Minerva Singh                                  19
# Evergreen Technologies                         19
# Paweł Krakowiak                                18
# 我妻 幸長 Yukinaga Azuma                           18
# Start-Tech Academy                             18
# Data Is Good Academy                           16
# 唐宇迪 唐                                          16
# Mike West                                      15
# Lazy Programmer Team, Lazy Programmer Inc.     15
# Geoffrey Hubona, Ph.D.                         14
# Jose Portilla                                  14
# Центр digital-профессий ITtensive              13
# Oak Academy                                    13
# Pianalytix .                                   13
# Eduonix Learning Solutions, Eduonix-Tech .     12
# Uplatz Training                                12
# Name: count, dtype: int64

# %%
dataS[dataS['instructors'] == 'Packt Publishing']
# Out:
#                                            course title  \
# 337                       Deep Learning with TensorFlow
# 410   Learning Path: R: Complete Machine Learning & ...
# 503                Data Science for Marketing Analytics
# 511   Learning Path: Python: Predictive Analysis wit...
# 541   Python: A-Z Artificial Intelligence with Pytho...
# ...                                                 ...
# 1532  LEARNING PATH: R: Machine Learning Algorithms ...
# 1546               Practical Deep Learning on the Cloud
# 1548     Beginning Data Science with Python and Jupyter
# 1555        Speaking ‘R’ - The Language of Data Science
# 1571  Advanced Machine Learning with TensorFlow: 3-in-1
#
#                                              course url  \
# 337   https://www.udemy.com/course/deep-learning-wit...
# 410   https://www.udemy.com/course/learning-path-r-c...
# 503   https://www.udemy.com/course/data-science-for-...
# 511   https://www.udemy.com/course/learning-path-pyt...
# 541   https://www.udemy.com/course/python-a-z-artifi...
# ...                                                 ...
# 1532  https://www.udemy.com/course/learning-path-r-m...
# 1546  https://www.udemy.com/course/practical-deep-le...
# 1548  https://www.udemy.com/course/beginning-data-sc...
# 1555  https://www.udemy.com/course/speaking-r-the-la...
# 1571  https://www.udemy.com/course/advanced-machine-...
#
#                                      course description               Ratings  \
# 337   Channel the power of deep learning with Google...  Rating: 4.0 out of 5
# 410   Unleash the true potential of R to unlock the ...  Rating: 4.4 out of 5
# 503   Achieve your marketing goals with the data ana...  Rating: 4.3 out of 5
# 511   Manipulate, analyze, and visualize your data w...  Rating: 4.4 out of 5
# 541   Build real-world Artificial Intelligence appli...  Rating: 4.3 out of 5
# ...                                                 ...                   ...
# 1532  Conquer the world of machine learning algorith...  Rating: 4.2 out of 5
# 1546  Build deep learning applications from scratch ...  Rating: 3.0 out of 5
# 1548  Perform reproducible data analyses with these ...  Rating: 3.7 out of 5
# 1555  Get a sense of the awesome power of R by learn...  Rating: 2.0 out of 5
# 1571  Tackle common machine learning problems to enh...  Rating: 2.0 out of 5
#
#           reviews          duration      Lectures  course level  \
# 337   237 reviews     2 total hours   22 lectures      Beginner
# 410   168 reviews  17.5 total hours  213 lectures        Expert
# 503   113 reviews   4.5 total hours   45 lectures      Beginner
# 511   110 reviews   8.5 total hours   86 lectures  Intermediate
# 541    98 reviews   8.5 total hours  130 lectures      Beginner
# ...           ...               ...           ...           ...
# 1532    2 reviews   3.5 total hours   42 lectures  Intermediate
# 1546    2 reviews   2.5 total hours   27 lectures  Intermediate
# 1548    2 reviews     3 total hours   18 lectures      Beginner
# 1555     1 review   2.5 total hours   19 lectures  Intermediate
# 1571     1 review     6 total hours   71 lectures      Beginner
#
#            instructors
# 337   Packt Publishing
# 410   Packt Publishing
# 503   Packt Publishing
# 511   Packt Publishing
# 541   Packt Publishing
# ...                ...
# 1532  Packt Publishing
# 1546  Packt Publishing
# 1548  Packt Publishing
# 1555  Packt Publishing
# 1571  Packt Publishing
#
# [134 rows x 9 columns]

# %%
x = dataS[dataS['reviews'] == '0 reviews']
x['Ratings'].value_counts(0)
####อนุมานได้ว่าคอร์สไหนที่มีการรีวิวเท่ากับ0 แปลว่าค่า ratingsจะได้0เช่นกัน
# Out:
# Ratings
# Rating: 0.0 out of 5    197
# Name: count, dtype: int64

# %%
x = dataS[dataS['Ratings'] == 'Rating: 0.0 out of 5']
x['reviews'].value_counts(0)
# Out:
# reviews
# 0 reviews    197
# Name: count, dtype: int64

# %%
def make_graph(list_d):
    left = [] 
    height = []
    name_instr = []
    for i in range(len(list_d)):
        left.append(i+1)
        height.append(list_d[i][1])
        name_instr.append(list_d[i][0])
    # height
    
    plt.bar(left,height,name_instr = name_instr,width=0.8,color = ['blue','pink'])
    plt.xlabel('instructors')
    plt.ylabel('Average Ratings')
    plt.title('test1')
    plt.show()

# %%
def main():
    x = dataS['instructors'].value_counts().head(20)

    instructors = []
    num_inst = []
    for i in dataS['instructors']:
        if i in instructors:
            continue
        else:
            instructors.append(i)
    for i in instructors:
        nub = 0
        for j in dataS['instructors']:
            if i == j:
                nub += 1
        num_inst.append(nub)

    list_data = []
    for i in x:
        inD = num_inst.index(i)
        name = instructors[inD]
        sum_rate = 0
        data = dataS[dataS['instructors'] == name]
        rate = data['Ratings'].apply(lambda x : x[8:11])

        for j in rate:
            if j != 'ws':
                fj = float(j)
                sum_rate += fj
        list_data.append([name,round(sum_rate/i,2),i])
    # print(list_data)
    make_graph(list_data)
