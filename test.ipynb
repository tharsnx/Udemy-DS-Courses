# %%
import pandas as pd 
dataS = pd.read_csv('udemy.csv')
dataS
# Out:
#                                            course title  \
# 0     Machine Learning A-Z™: Hands-On Python & R In ...
# 1     Python for Data Science and Machine Learning B...
# 2     The Data Science Course 2022: Complete Data Sc...
# 3     R Programming A-Z™: R For Data Science With Re...
# 4     Deep Learning A-Z™: Hands-On Artificial Neural...
# ...                                                 ...
# 2786   Learn Python along with EDA for Indian beginners
# 2787  AutoViMLによる分類モデル/回帰モデル作成講座:【AutoML/Python/SIGN...
# 2788              Python ile Twitter Verilerini Kazımak
# 2789                                    EDA for Neurons
# 2790              Görüntü İşleme (OpenCV) Giriş Eğitimi
#
#                                              course url  \
# 0         https://www.udemy.com/course/machinelearning/
# 1     https://www.udemy.com/course/python-for-data-s...
# 2     https://www.udemy.com/course/the-data-science-...
# 3           https://www.udemy.com/course/r-programming/
# ...

# %%
dataS = dataS[dataS['course level'] != 'Current price: $16.99']
dataS = dataS[dataS['course level'] != 'Current price: $19.99']

# %%
dataS
# Out:
#                                            course title  \
# 0     Machine Learning A-Z™: Hands-On Python & R In ...
# 1     Python for Data Science and Machine Learning B...
# 2     The Data Science Course 2022: Complete Data Sc...
# 3     R Programming A-Z™: R For Data Science With Re...
# 4     Deep Learning A-Z™: Hands-On Artificial Neural...
# ...                                                 ...
# 2786   Learn Python along with EDA for Indian beginners
# 2787  AutoViMLによる分類モデル/回帰モデル作成講座:【AutoML/Python/SIGN...
# 2788              Python ile Twitter Verilerini Kazımak
# 2789                                    EDA for Neurons
# 2790              Görüntü İşleme (OpenCV) Giriş Eğitimi
#
#                                              course url  \
# 0         https://www.udemy.com/course/machinelearning/
# 1     https://www.udemy.com/course/python-for-data-s...
# 2     https://www.udemy.com/course/the-data-science-...
# 3           https://www.udemy.com/course/r-programming/
# ...

# %%
x = dataS[dataS['instructors'] == '365 Careers, 365 Careers Team']
print(x['course level'])
x['Ratings']
# Out:
# 2     All Levels
# 5     All Levels
# 79    All Levels
# Name: course level, dtype: object
# 2     Rating: 4.6 out of 5
# 5     Rating: 4.6 out of 5
# 79    Rating: 4.5 out of 5
# Name: Ratings, dtype: object

# %%
dataS['instructors'].value_counts()
# Out:
# instructors
# Packt Publishing                     139
# Mammoth Interactive, John Bura        36
# Exam Turf                             27
# Jones Granatyr, IA Expert Academy     26
# Evergreen Technologies                20
#                                     ...
# Namrata Nv                             1
# Manuel Offidani                        1
# Frank Rogers                           1
# Zulqarnain Hayat                       1
# SYRC PRO                               1
# Name: count, Length: 1343, dtype: int64

# %%
dataS['Lectures'].value_counts()
# Out:
# Lectures
# 10 lectures     50
# 13 lectures     48
# 15 lectures     48
# 18 lectures     46
# 27 lectures     46
#                 ..
# 252 lectures     1
# 168 lectures     1
# 555 lectures     1
# 800 lectures     1
# 308 lectures     1
# Name: count, Length: 280, dtype: int64

# %%
dataS['instructors'].value_counts()
# Out:
# instructors
# Packt Publishing                     139
# Mammoth Interactive, John Bura        36
# Exam Turf                             27
# Jones Granatyr, IA Expert Academy     26
# Evergreen Technologies                20
#                                     ...
# Nitin Singhal                          1
# Namrata Nv                             1
# Manuel Offidani                        1
# Frank Rogers                           1
# Muhammad Omer                          1
# Name: count, Length: 1348, dtype: int64

# %%
# data = dataS[dataS['course level'] == 'Current price: $16.99']
# dataS['duration'].value_counts()
# dataS = dataS[dataS['course level'] != 'Current price: $19.99']
print(dataS['duration'].value_counts())
# Out:
# duration
# 2 total hours      222
# 1 total hour       217
# 1.5 total hours    173
# 2.5 total hours    156
# 3 total hours      139
#                   ...
# 49 total hours       1
# 110 questions        1
# 125 questions        1
# 611 questions        1
# 26 total mins        1
# Name: count, Length: 139, dtype: int64

# %%
dataS
# Out:
#                                            course title  \
# 0     Machine Learning A-Z™: Hands-On Python & R In ...
# 1     Python for Data Science and Machine Learning B...
# 2     The Data Science Course 2022: Complete Data Sc...
# 3     R Programming A-Z™: R For Data Science With Re...
# 4     Deep Learning A-Z™: Hands-On Artificial Neural...
# ...                                                 ...
# 2786   Learn Python along with EDA for Indian beginners
# 2787  AutoViMLによる分類モデル/回帰モデル作成講座:【AutoML/Python/SIGN...
# 2788              Python ile Twitter Verilerini Kazımak
# 2789                                    EDA for Neurons
# 2790              Görüntü İşleme (OpenCV) Giriş Eğitimi
#
#                                              course url  \
# 0         https://www.udemy.com/course/machinelearning/
# 1     https://www.udemy.com/course/python-for-data-s...
# 2     https://www.udemy.com/course/the-data-science-...
# 3           https://www.udemy.com/course/r-programming/
# ...

# %%
x= dataS['duration'].apply(lambda x : (str(x)).split(' '))
y = x.apply(lambda i : len(i))
y.value_counts()
# print(x)
# Out:
# duration
# 3    2768
# 2      21
# 1       1
# Name: count, dtype: int64

# %%
dataS['course level'].value_counts()
# Out:
# course level
# All Levels               1247
# Beginner                 1002
# Intermediate              447
# Expert                     72
# Current price: $16.99       5
# Name: count, dtype: int64
